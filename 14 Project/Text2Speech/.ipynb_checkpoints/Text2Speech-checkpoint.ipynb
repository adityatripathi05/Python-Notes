# %% [markdown]
# ### Text-to-Speech
# - Text-to-speech (TTS) technology reads aloud digital text.
# - It can take words on computers, smartphones, tablets and convert them into audio.
# - Also, all kinds of text files can be read aloud, including Word, pages document, online web pages can be read aloud.
# - TTS can help kids who struggle with reading.
# - Many tools and apps are available to convert text into speech. Python comes with a lot of handy and easily accessible libraries.
#
#
# ### Python Implementation
# - Different API’s are available in Python in order to convert text to speech.
# - One of Such API’s is the Google Text to Speech commonly known as the gTTS API.
#     - Ref.: <https://gtts.readthedocs.io/en/latest/module.html>
#     - It is very easy to use the library which converts the text entered, into an audio file which can be saved as a mp3 file.
#     - It supports several languages and the speech can be delivered in any one of the two available audio speeds, fast or slow.
#     - GTTS is an easy tool to convert text to voice, but it requires an internet connection to operate because it depends entirely on Google to get the audio data.
#
# - <https://cloud.google.com/text-to-speech/docs/reference/libraries#client-libraries-usage-python>
# - Library: `!pip install gTTS`

# %%
# !pip install gTTS
# Out:
# ...
#   Created wheel for gtts-token: filename=gTTS_token-1.1.3-cp37-none-any.whl size=4100 sha256=e7cbf8fd047550bdbef8128012be196a7ea05e2bdbd76e3f6bd6c11c9653d1f2
#   Stored in directory: C:\Users\Aditya\AppData\Local\pip\Cache\wheels\dd\11\61\33f7e51bf545e910552b2255eead2a7cd8ef54064b46dceb34
# Successfully built gtts-token
# ...

# %% [markdown]
# ## Convert Text into Speech

# %%
import os
from gtts import gTTS

# %%
text = "Global warming is the long-term rise in the average temperature of the Earth’s climate system"

# %%
speech = gTTS(text= text, lang= 'en', slow= False)
# Marked slow = False which tells the module that the converted audio should have a high speed.
speech.save('text.mp3')

# %%
os.system('start text.mp3')
# Out:
# 0

# %% [markdown]
# ## Convert a Text File into Speech

# %%
import os
from gtts import gTTS

# %%
file = open("draft.txt", "r").read().replace("\n", " ")

# %%
speech = gTTS(text = str(file), lang = 'en', slow = False)
speech.save("voice.mp3")

# %%
os.system("start voice.mp3")
# Out:
# 0
