# %%
import sys
import os
import win32com.client
import tkinter as tk
from pathlib import Path
import tkinter.messagebox as msgbox

# %%
def Word_to_pdf():   
    app=tk.Tk()
    app.title('Word to PDF Converter')
    app.configure(width=500, height=200, bg='#AED6F1')

    # Add the interactive components
    label1 = tk.Label(app,text="Choose Source Word File to convert")
    label1.grid(row=0,column=0)
    word_path=tk.StringVar()
    entry1 = tk.Entry(app,textvariable=word_path)
    entry1.grid(row=0,column=1)

    label2 = tk.Label(app,text="Select Output Directory")
    label2.grid(row=1,column=0)
    pdf_path=tk.StringVar()
    entry2 = tk.Entry(app,textvariable=pdf_path)
    entry2.grid(row=1,column=1)

    label3 = tk.Label(app,text="Output file name")
    label3.grid(row=2,column=0)
    pdf_name=tk.StringVar()
    entry3 = tk.Entry(app,textvariable=pdf_name)
    entry3.grid(row=2,column=1)

#     btn1 = tk.Button(app,text="Process",command=press)
#     btn1.grid(row=3,column=0)
    
#     btn2 = tk.Button(app,text="Quit",command=quit)
#     btn2.grid(row=3,column=1)
    app.mainloop()
Word_to_pdf()

# %%
# !pip install comtypes

# %%
# !pip install pywin32

# %%
# Out:
# Collecting docx2pdf
#   Downloading docx2pdf-0.1.7-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: importlib_metadata<2.0.0,>=1.3.0; python_version < "3.8" in c:\users\aditya\.conda\envs\learning\lib\site-packages (from docx2pdf) (1.5.0)
# Requirement already satisfied: pywin32<228,>=227; sys_platform == "win32" in c:\users\aditya\.conda\envs\learning\lib\site-packages (from docx2pdf) (227)
# Requirement already satisfied: tqdm<5.0.0,>=4.41.0 in c:\users\aditya\.conda\envs\learning\lib\site-packages (from docx2pdf) (4.46.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\aditya\.conda\envs\learning\lib\site-packages (from importlib_metadata<2.0.0,>=1.3.0; python_version < "3.8"->docx2pdf) (2.2.0)
# Installing collected packages: docx2pdf
# Successfully installed docx2pdf-0.1.7

# %%
'''pip install docx2pdf'''


import sys
import os
from docx2pdf import convert
import tkinter as tk
from pathlib import Path
import tkinter.messagebox as msgbox
from tkinter import filedialog


def Word_to_pdf():   
    def word_to_pdf(input_file,output_file):
        in_file =str(input_file)
        out_file = str(output_file)+'.pdf'
        in_file =  in_file.replace('/','\\')
        convert(in_file,out_file)
        print(".DOCX to PDF conversion sucessful and Saved")


    def validate_inputs(src_file, dest_dir, out_file):
        errors = False
        error_msgs = []
        
        # Check for a doc file
        if Path(src_file).suffix.upper() != ".DOCX":
            errors = True
            entry1.delete(0,tk.END)
            error_msgs.append("Please select a .DOC or .DOCX   input file")
        
        # Check for a directory
        if not(Path(dest_dir)).exists():
            errors = True
            error_msgs.append("Please Select a valid output directory")

        # Check for a file name
        if len(out_file) < 1:
            errors = True
            error_msgs.append("Please enter a file name")
           
        return(errors, error_msgs)

    def press():
        src_file = word_path.get()
        dest_dir = pdf_path.get()
        out_file = pdf_name.get()
        errors, error_msg = validate_inputs(src_file, dest_dir, out_file)
        if errors:
            msgbox.showerror('Error',"\n".join(error_msg))
        else:
            word_to_pdf(src_file,Path(dest_dir,out_file))
    
    def quit():
        app.destroy()
        
    def browse_to_word(self):
        wfile_path = filedialog.askopenfilename()
        entry1.insert(tk.END, wfile_path)
        
    def browse_to_pdf(self):
        pfolder_path = filedialog.askdirectory()
        entry2.insert(tk.END, pfolder_path)

    app=tk.Tk()
    app.title('Word to PDF Converter')
    app.geometry("600x100")
    app.resizable(0,0)

    # Add the interactive components
    label1 = tk.Label(app,text="Choose Source Word File to convert")
    label1.grid(row=0,column=0)
    
    word_path=tk.StringVar()
    entry1 = tk.Entry(app,width=65,textvariable=word_path)
    entry1.bind("<Enter>", browse_to_word)
    entry1.grid(row=0,column=1)

    label2 = tk.Label(app,text="Select Output Directory")
    label2.grid(row=1,column=0)
    
    pdf_path=tk.StringVar()
    entry2 = tk.Entry(app,width=65,textvariable=pdf_path)
    entry2.bind("<Enter>", browse_to_pdf)
    entry2.grid(row=1,column=1)

    label3 = tk.Label(app,text="Output file name")
    label3.grid(row=2,column=0)
    pdf_name=tk.StringVar()
    entry3 = tk.Entry(app,width=65,textvariable=pdf_name)
    entry3.grid(row=2,column=1)

    btn1 = tk.Button(app,text="Process",command=press)
    btn1.grid(row=3,column=0)
    
    btn2 = tk.Button(app,text="Quit",command=quit)
    btn2.grid(row=3,column=1)
    app.mainloop()
Word_to_pdf()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Aditya\.conda\envs\Learning\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-3-27b61f8a85ac>", line 41, in press
#     word_to_pdf(src_file,Path(dest_dir,out_file))
#   File "<ipython-input-3-27b61f8a85ac>", line 6, in word_to_pdf
#     convert(in_file,out_file)
#   File "C:\Users\Aditya\.conda\envs\Learning\lib\site-packages\docx2pdf\__init__.py", line 106, in convert
#     return windows(paths, keep_active)
#   File "C:\Users\Aditya\.conda\envs\Learning\lib\site-packages\docx2pdf\__init__.py", line 33, in windows
#     doc.SaveAs(str(pdf_filepath), FileFormat=wdFormatPDF)
#   File "C:\Users\Aditya\AppData\Local\Temp\gen_py\3.7\00020905-0000-0000-C000-000000000046x0x8x4\_Document.py", line 434, in SaveAs
#     , Encoding, InsertLineBreaks, AllowSubstitutions, LineEnding, AddBiDiMarks
# pywintypes.com_error: (-2147352567, 'Exception occurred.', (0, 'Microsoft Word', 'Command failed', 'C:\\Program Files (x86)\\Microsoft Office\\Office12\\1033\\WDMAIN11.CHM', 36966, -2146824090), None)
