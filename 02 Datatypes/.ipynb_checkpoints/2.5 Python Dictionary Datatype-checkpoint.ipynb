# %% [markdown]
# ## Python Dictionary:
# - Dictionary in Python is an unordered collection of key-value pairs.
#     - Dictionaries in python are similar to as hash tables in other languages.
# - Pairs in dictionary are seperated by comma(,) and individual key-value are seperated by colon(:) and dictionary items are delimited by curly braces { }.
#     - Key is at LHS of colon and Value is at RHS of colon.
# - Keys must be of immutable datatype and values can be of any data type supported by python.
# - The **keys in the dictionaries must be unique** as they are used to access the values associated with them.
#     - **NOTE:** If key of two values are same then the last Value stored get access on calling value through key since python is interpreted language.
# - Dictionary is mutable.
# - Dictionary is iterable object.
# - After python version 3.5, dictionary are ordered pair of collection.

# %% [markdown]
# ### Create empty dictionary:

# %%
d0 = {}
d1 = dict()

# %%
print(type(d0), len(d0))
print(type(d1), len(d1))
# Out:
# <class 'dict'> 0
# <class 'dict'> 0

# %% [markdown]
# ### Create non-empty dictionary:

# %%
data1 = {'name':'aman', 'age':21, 'num':[50, 65, 67]}
data2 = dict({'name':'aman', 'age':21, 'num':[50, 65, 67]})
data3 = dict(name = 'aman', age = 21, num =[50, 65, 67])

# %%
print(data1,len(data1))
print(data2,len(data2))
print(data3,len(data3))
# Out:
# {'name': 'aman', 'age': 21, 'num': [50, 65, 67]} 3
# {'name': 'aman', 'age': 21, 'num': [50, 65, 67]} 3
# {'name': 'aman', 'age': 21, 'num': [50, 65, 67]} 3

# %%
d = {}
r = int(input("Enter no. of pairs to store: "))
for i in range(r):
    k = input('Enter Key: ')
    v = input('Enter Value: ')
    d[k] = v
print(d)
# Out:
# Enter no. of pairs to store: 2
# Enter Key: name
# Enter Value: aditya
# Enter Key: age
# Enter Value: two
# {'name': 'aditya', 'age': 'two'}

# %% [markdown]
# ### Access value of Dictionary:

# %%
data1['age']
# Out:
# 21

# %%
# data1['day'] # Since 'day' key doesn't exist, this instruction will return error.

# %% [markdown]
# - **get():** get() method returns:
#     - the value for the specified key if key is in dictionary.
#     - None if the key is not found and value is not specified.
#     - value if the key is not found and value is specified.

# %%
# if key exist
data1.get('age')
# Out:
# 21

# %%
# if the key doesn't exist and value is not specified.
print(data1.get('day'))
# Out:
# None

# %%
# if the key doesn't exist and value is specified.
print(data1.get('day', 'Key not found'))
# Out:
# Key not found

# %% [markdown]
# ### Python Operators in Dictionary:
# - **Assignment Operator(=):**

# %%
# Update value of a key:
data1['name'] = 'vivek'
print(data1)
# Out:
# {'name': 'vivek', 'age': 21, 'num': [50, 65, 67]}

# %%
# Add a key-value pair:
data1['sub'] = ['C', 'C++']
print(data1)
# Out:
# {'name': 'vivek', 'age': 21, 'num': [50, 65, 67], 'sub': ['C', 'C++']}

# %% [markdown]
# - **Membership Operator(in/not in):**
#     - Check for membership of a key or value.

# %%
print(data1)
print('age' in data1.keys())
print(25 in data1.values())
# Out:
# {'name': 'vivek', 'age': 21, 'num': [50, 65, 67], 'sub': ['C', 'C++']}
# True
# False

# %% [markdown]
# ### Python Dictionary Methods

# %% [markdown]
# - **keys():** Return sequence of all keys of dictionary

# %%
print(data1.keys())
print(list(data1.keys()))
# Out:
# dict_keys(['name', 'age', 'num'])
# ['name', 'age', 'num']

# %% [markdown]
# - **values():** Return sequence of all values of dictionary

# %%
print(data1.values())
print(list(data1.values()))
# Out:
# dict_values(['aman', 21, [50, 65, 67]])
# ['aman', 21, [50, 65, 67]]

# %% [markdown]
# - **items():** Return a sequence of tuple inwhich each tuple is having key and value of dictionary

# %%
print(data1.items())
print(list(data1.items()))
# Out:
# dict_items([('name', 'aman'), ('age', 21), ('num', [50, 65, 67])])
# [('name', 'aman'), ('age', 21), ('num', [50, 65, 67])]

# %% [markdown]
# ### copy(): Create a copy of dictionary at different memory location.

# %%
data2 = data1.copy() # Shallow copy
print(data2)
# Out:
# {'name': 'vivek', 'age': 21, 'num': [50, 65, 67], 'sub': ['C', 'C++']}

# %%
data2['name'] = 'rohit'
print(data2)
print(data1)
# Out:
# {'name': 'rohit', 'age': 21, 'num': [50, 65, 67], 'sub': ['C', 'C++']}
# {'name': 'vivek', 'age': 21, 'num': [50, 65, 67], 'sub': ['C', 'C++']}

# %% [markdown]
# ### update(): Update Dictionary using Other Dictionary

# %%
dict0 = {'name':'adi', 'age':21, 'roll':200}
dict1 = {'name':'priya', 'age':50, 'sub':['Jave', 'Python']}
print(dict0)
dict0.update(dict1)  # updating dict0
print(dict0)
# Out:
# {'name': 'adi', 'age': 21, 'roll': 200}
# {'name': 'priya', 'age': 50, 'roll': 200, 'sub': ['Jave', 'Python']}

# %% [markdown]
# ### pop(): It will remove the pair and also return value.
# - Syntax: object.pop(key)

# %%
print(data1)
temp = data1.pop('name')
print(data1)
print(temp)
# Out:
# {'name': 'vivek', 'age': 21, 'num': [50, 65, 67], 'sub': ['C', 'C++']}
# {'age': 21, 'num': [50, 65, 67], 'sub': ['C', 'C++']}
# vivek

# %% [markdown]
# ### popitem(): It will remove any arbitrary pair and also return the pair.
# - Syntax: object.popitem()
# - It doesnot take any argument.

# %%
print(data1)
temp = data1.popitem()
print(data1)
print(temp)
# Out:
# {'age': 21, 'num': [50, 65, 67], 'sub': ['C', 'C++']}
# {'age': 21, 'num': [50, 65, 67]}
# ('sub', ['C', 'C++'])

# %% [markdown]
# ### clear(): Remove all items from dictionary

# %%
print(data1)
data1.clear()
print(data1)
# Out:
# {'age': 21, 'num': [50, 65, 67]}
# {}

# %% [markdown]
# ### del:
# - **Delete a particular key-value pair**

# %%
print(data2)
del data2['age']
print(data2)
# Out:
# {'name': 'rohit', 'age': 21, 'num': [50, 65, 67], 'sub': ['C', 'C++']}
# {'name': 'rohit', 'num': [50, 65, 67], 'sub': ['C', 'C++']}

# %% [markdown]
# - **If value corresponding to a key is list:**

# %%
print(data2)
del data2['sub'][1:2]   # start:stop of list
print(data2)
# Out:
# {'name': 'rohit', 'num': [50, 65, 67], 'sub': ['C', 'C++']}
# {'name': 'rohit', 'num': [50, 65, 67], 'sub': ['C']}

# %%
print(data2)
del data2['num'][:]   # empty the value
print(data2)
# Out:
# {'name': 'rohit', 'num': [50, 65, 67], 'sub': ['C']}
# {'name': 'rohit', 'num': [], 'sub': ['C']}

# %%
print(data2)
del data2  # delete entire dictionary
# print(data2)
# Out:
# {'name': 'rohit', 'num': [], 'sub': ['C']}

# %% [markdown]
# ### setdefault():
# - It return the value of a key, if the key is in dictionary else it insert the key with a value in the dictionary (Default value is None).
# - **Syntax:** object.setdefault(key,value=None)

# %%
print(data3)
print(data3.setdefault('age'))
print(data3)
# Out:
# {'name': 'aman', 'age': 21, 'num': [50, 65, 67]}
# 21
# {'name': 'aman', 'age': 21, 'num': [50, 65, 67]}

# %%
print(data3)
print(data3.setdefault('perc'))
print(data3)
# Out:
# {'name': 'aman', 'age': 21, 'num': [50, 65, 67]}
# None
# {'name': 'aman', 'age': 21, 'num': [50, 65, 67], 'perc': None}

# %%
print(data3)
print(data3.setdefault('board','CBSE'))
print(data3)
# Out:
# {'name': 'aman', 'age': 21, 'num': [50, 65, 67], 'perc': None}
# CBSE
# {'name': 'aman', 'age': 21, 'num': [50, 65, 67], 'perc': None, 'board': 'CBSE'}

# %%
print(data3)
print(data3.setdefault('num,'CBSE'))
print(data3)
# Out:
# {'name': 'aman', 'age': 21, 'num': [50, 65, 67], 'perc': None, 'board': 'CBSE'}
# None
# {'name': 'aman', 'age': 21, 'num': [50, 65, 67], 'perc': None, 'board': 'CBSE'}

# %% [markdown]
# ### WAP to store username and password in dictionary:
# - if password length is greater than 5.

# %%
data={}
print('----Sign up----')
name= input("Choose Username: ")
pwd= input("Choose Password: ")
if len(pwd)>=5:
    data[name]=pwd
    print('Account Created')
else:
    print('Read User Guideline')
print(data)

# %% [markdown]
# ### WAP to store Username and Password in Dictionary
# - if username doesn't exist already.
# - if password length is greater than 5.

# %%
data={'aditya':123445}
print('----Sign up----')
name= input("Choose Username: ")
if name not in data.keys():
    pwd= input("Choose Password: ")
    if len(pwd)>=5:
        data[name]=pwd
        print('Account Created')
    else:
        print('Read User Guideline')
else:
    print('Try Using different Username')
        
print(data)

# %% [markdown]
# ### WAP for Signup and Login:

# %%
data={'aditya':123445}
print('Choose Option:\n1. Signup \n2.Login')
ch=int(input("Enter choice no.: "))
if ch==1:
    print('----Sign up----')
    name= input("Choose Username: ")
    if name not in data.keys():
        pwd= input("Choose Password: ")
        if len(pwd)>=5:
            data[name]=pwd
            print('Account Created')
        else:
            print('Read User Guidelines.')
    else:
        print('Try Using different Username')
elif ch==2:
    print("-------Login-------")
    name = input("Enter username: ")
    if name in data.keys():
        pwd = input("Enter password: ")
        if pwd==data[name]:
            print("Welcome, Login Successful")
        else:
            print("Wrong Password")
    else:
        print("Unknown User")
else:
    print('Unknown Choice')
