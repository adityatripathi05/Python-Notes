# %%
import sys

students_list = []

def create_student():
    name = add_name(student_list)
    marks = add_marks(student_list)
    student_data = {'name': name, 'marks': marks}
    return student_data

def add_name(student):
    name = input('Enter student name: ')
    return name

def add_marks(student):
    marks_detail= []
    marks = input('Enter the marks obtained in all subjects as CSV: ').split(',')
    for each_marks in marks:
        marks_detail.append(int(each_marks))
    return marks_detail

def calculate_percentage(student):
    subject_count = len(student['marks'])
    average = sum(student['marks'])/(subject_count*100)
    percentage = average*100
    return percentage

def print_student_details(student):
    print('Name is {} and marks scored is {} and overall percentage is {}'.format(student['name'], student['marks'], calculate_percentage(student)))
          
def print_student_list(student_list):
    for i, student in enumerate(student_list):
        print('Roll no. '+ str(i)+':', end =' ')
        print_student_details(student)

# %%
def menu():
    while True:
        choose = input(f'1 Print student list \n2 Add new student \n3 Print detail of a student \n4 Rectify a student detail \n5 Quit \nChoose operation number: ')
        if (choose == '1'):
            print_student_list(students_list)
        elif (choose == '2'):
            students_list.append(create_student())
        elif (choose == '3'):
            student_id = int(input("Enter the student id: "))
            print_student_details(students_list[student_id])
        elif (choose == '4'):
            student_id = int(input("Enter the student id: "))
            add_marks(students_list[student_id])
        else:
            exit()

# %%
menu()
# Out:
# 1 Print student list
# 2 Add new student
# 3 Print detail of a student
# 4 Rectify a student detail
# 5 Quit
# Choose operation number: 1
# 1 Print student list
# 2 Add new student
# 3 Print detail of a student
# 4 Rectify a student detail
# 5 Quit
# Choose operation number: 2
# Enter student name: aditya
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-a554a8713acc> in <module>
# ----> 1 menu()
#
# <ipython-input-2-988b1d4afc7f> in menu()
#       5             print_student_list(students_list)
#       6         elif (choose == '2'):
# ----> 7             students_list.append(create_student(students_list))
#       8         elif (choose == '3'):
#       9             student_id = int(input("Enter the student id: "))
#
# <ipython-input-1-5c10fe096c1a> in create_student(student)
#       4
#       5 def create_student(student):
# ----> 6     add_name(student)
#       7     add_marks(student)
#       8     student_data = {'name': ' ', 'marks': []}
#
# <ipython-input-1-5c10fe096c1a> in add_name(student)
#      11 def add_name(student):
#      12     name = input('Enter student name: ')
# ---> 13     student['name']= name
#      14
#      15 def add_marks(student):
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# **---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %%
import sys

students_list = []

class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

def create_student():
    name = add_name(student_list)
    marks = add_marks(student_list)
    student_data = Student()
    return student_data

def add_name(student):
    name = input('Enter student name: ')
    return name

def add_marks(student):
    marks_detail= []
    marks = input('Enter the marks obtained in all subjects as CSV: ').split(',')
    for each_marks in marks:
        marks_detail.append(int(each_marks))
    return marks_detail

def calculate_percentage(student):
    subject_count = len(student.marks)
    average = sum(student.marks)/(subject_count*100)
    percentage = average*100
    return percentage

def print_student_details(student):
    print('Name is {} and marks scored is {} and overall percentage is {}'.format(student.name, student.marks, calculate_percentage(student)))
          
def print_student_list(student_list):
    for i, student in enumerate(student_list):
        print('Roll no. '+ str(i)+':', end =' ')
        print_student_details(student)
